# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import re

# %%
df = pd.read_csv('restaurant_data.csv')

# %%
df
# Out:
#                                           NAME  RATING  \
# 0                                  Table Tales     4.8
# 1                      Banjara- Gourmet Dining     4.5
# 2               Laurel - An Essence Of Flavors     5.0
# 3                           The Chocolate Room     5.0
# 4                                      Essence     4.5
# ..                                         ...     ...
# 535                       Blah Bla (Indigo XP)     3.9
# 536                               Scottish Pub     4.8
# 537  Salt - Pan Indian Restaurant, Bar & Grill     4.2
# 538                                 Frenzy Pub     4.5
# 539                                 Howl’n Pub     4.3
#
#                                                   AREA                 DISHES  \
# 0                             Bodakdev, West Ahmedabad           Multicuisine
# 1                             Bodakdev, West Ahmedabad           Multicuisine
# ...

# %%
df['AREA'] = df['AREA'].str.replace('\xa0 \| View All\(\d+\) Outlets', '', regex=True)

# %%
df
# Out:
#                                           NAME  RATING  \
# 0                                  Table Tales     4.8
# 1                      Banjara- Gourmet Dining     4.5
# 2               Laurel - An Essence Of Flavors     5.0
# 3                           The Chocolate Room     5.0
# 4                                      Essence     4.5
# ..                                         ...     ...
# 535                       Blah Bla (Indigo XP)     3.9
# 536                               Scottish Pub     4.8
# 537  Salt - Pan Indian Restaurant, Bar & Grill     4.2
# 538                                 Frenzy Pub     4.5
# 539                                 Howl’n Pub     4.3
#
#                                   AREA                 DISHES  \
# 0             Bodakdev, West Ahmedabad           Multicuisine
# 1             Bodakdev, West Ahmedabad           Multicuisine
# 2                     Ambli, Ahmedabad           Multicuisine
# ...

# %%
# df['DISHES'] = df['DISHES'].str.split(',')

# %%
df['DISHES']
# Out:
# 0               Multicuisine
# 1               Multicuisine
# 2               Multicuisine
# 3                     Bakery
# 4       Indian, North Indian
#                ...
# 535             Multicuisine
# 536             Multicuisine
# 537    Indian, Cocktail Menu
# 538             Multicuisine
# 539             Multicuisine
# Name: DISHES, Length: 540, dtype: object

# %%
# df['DISHES'] = df['DISHES'].apply(lambda x: x[0])

# %%
# df.explode('DISHES')

# %%
df['DISHES'][0][0]
# Out:
# 'M'

# %%
df['APPROX'] = df['APPROX'].str.replace('\D', '', regex=True)

# %%
df
# Out:
#                                           NAME  RATING  \
# 0                                  Table Tales     4.8
# 1                      Banjara- Gourmet Dining     4.5
# 2               Laurel - An Essence Of Flavors     5.0
# 3                           The Chocolate Room     5.0
# 4                                      Essence     4.5
# ..                                         ...     ...
# 535                       Blah Bla (Indigo XP)     3.9
# 536                               Scottish Pub     4.8
# 537  Salt - Pan Indian Restaurant, Bar & Grill     4.2
# 538                                 Frenzy Pub     4.5
# 539                                 Howl’n Pub     4.3
#
#                                   AREA                 DISHES APPROX  \
# 0             Bodakdev, West Ahmedabad           Multicuisine   1500
# 1             Bodakdev, West Ahmedabad           Multicuisine   1700
# 2                     Ambli, Ahmedabad           Multicuisine   1800
# ...

# %%
df['APPROX'].unique()
# Out:
# array(['1500', '1700', '1800', '500', '2000', '900', '700', '1000',
#        '1400', '800', '1100', '1850', '600', '1200', '450', '300', '400',
#        '200', '350', '1600', '1300', '2500', '1450', '3000', '4000',
#        '2600', '3100', '3500', '1350', '2200', '995', '850', '750',
#        '2400', '4500', '1650', '2800', '3400', '5200', '1150', '2050',
#        '950', '2250', '5000'], dtype=object)

# %%
df['DISC'][2].split('+')[0]
# Out:
# '20% Off '

# %%
DISCOUNT = []
for i in df['DISC']:
    if '+' in i:
        d = i.split('+')[0]
        DISCOUNT.append(d)
    else:
        DISCOUNT.append(np.nan)
df['DISCOUNT'] = DISCOUNT

DISCOUNT = []
for i in df['DISCOUNT']:
    if isinstance(i, str) and 'Off' in i:
        d = re.sub('\D', '', i)
        DISCOUNT.append(d)
    else:
        DISCOUNT.append(np.nan)
df['DISCOUNT'] = DISCOUNT
# Out:
# 540

# %%
df['DISCOUNT'] = DISCOUNT

# %%
df.drop(columns='DISC', inplace=True)

# %%
df['DISCOUNT'].unique()
# Out:
# array(['10% Off ', '20% Off ', '35% Off ', '50% Off ', '15% Off ',
#        '25% Off ', '30% Off ', nan, '40% Off ', 'Cover Charge ',
#        '55% Off ', '1', 'Free Cocktail or Mocktail ', '60 Discount ',
#        '45% Off '], dtype=object)

# %%
df
# Out:
#                                           NAME  RATING  \
# 0                                  Table Tales     4.8
# 1                      Banjara- Gourmet Dining     4.5
# 2               Laurel - An Essence Of Flavors     5.0
# 3                           The Chocolate Room     5.0
# 4                                      Essence     4.5
# ..                                         ...     ...
# 535                       Blah Bla (Indigo XP)     3.9
# 536                               Scottish Pub     4.8
# 537  Salt - Pan Indian Restaurant, Bar & Grill     4.2
# 538                                 Frenzy Pub     4.5
# 539                                 Howl’n Pub     4.3
#
#                                   AREA                 DISHES APPROX  DISCOUNT
# 0             Bodakdev, West Ahmedabad           Multicuisine   1500  10% Off
# 1             Bodakdev, West Ahmedabad           Multicuisine   1700  20% Off
# ...

# %%
DISCOUNT = []
for i in df['DISCOUNT']:
    if isinstance(i, str) and 'Off' in i:
        d = re.sub('\D', '', i)
        DISCOUNT.append(d)
    else:
        DISCOUNT.append(np.nan)

len(DISCOUNT)
# Out:
# 540

# %%
df['DISCOUNT'] = DISCOUNT

# %%
df[['DISCOUNT']]
# Out:
#     DISCOUNT
# 0         10
# 1         20
# 2         20
# 3         35
# 4         50
# ..       ...
# 535       40
# 536       10
# 537      NaN
# 538       40
# 539       10
#
# [540 rows x 1 columns]

# %%
locations = ['Ahmedabad', 'Mumbai', 'Pune', 'Bengaluru']
loc = np.repeat(locations, 135)
df['LOCATION'] = loc

# %%
df.iloc[:137,:]
# Out:
#                                 NAME  RATING                           AREA  \
# 0                        Table Tales     4.8       Bodakdev, West Ahmedabad
# 1            Banjara- Gourmet Dining     4.5       Bodakdev, West Ahmedabad
# 2     Laurel - An Essence Of Flavors     5.0               Ambli, Ahmedabad
# 3                 The Chocolate Room     5.0  Prahlad Nagar, West Ahmedabad
# 4                            Essence     4.5        Crowne Plaza, Ahmedabad
# ..                               ...     ...                            ...
# 132                          Kabhi B     5.0      Satellite, West Ahmedabad
# 133                       Cafe Patio     4.3        Thaltej, West Ahmedabad
# 134          Ashray The Restaurant\t     2.5       Bodakdev, West Ahmedabad
# 135                       Cray Craft     4.5  Andheri East, Western Suburbs
# 136                          Novaara     4.0    Malad West, Western Suburbs
#
#                    DISHES APPROX DISCOUNT   LOCATION
# ...

# %%
df.to_csv('rest_cleandata.csv', index=False)

# %%
df
# Out:
#                                           NAME  RATING  \
# 0                                  Table Tales     4.8
# 1                      Banjara- Gourmet Dining     4.5
# 2               Laurel - An Essence Of Flavors     5.0
# 3                           The Chocolate Room     5.0
# 4                                      Essence     4.5
# ..                                         ...     ...
# 535                       Blah Bla (Indigo XP)     3.9
# 536                               Scottish Pub     4.8
# 537  Salt - Pan Indian Restaurant, Bar & Grill     4.2
# 538                                 Frenzy Pub     4.5
# 539                                 Howl’n Pub     4.3
#
#                                   AREA                 DISHES APPROX DISCOUNT  \
# 0             Bodakdev, West Ahmedabad           Multicuisine   1500       10
# 1             Bodakdev, West Ahmedabad           Multicuisine   1700       20
# ...
